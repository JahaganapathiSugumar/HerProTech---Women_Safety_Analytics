# %%
import requests

# Define the API URL and headers
url = 'https://graph.facebook.com/v20.0/380663718469903/messages'
headers = {
    'Authorization': 'Bearer EAAHXnznde8wBO6TONs75FcQjf00YCucJw74KjYTn9r59ILTmToa6tJNf4to2npERqGNt765Ulc8E8ODkjzVAfcloFnxdgdpWeqmMlqs6b8vAO4WynOQ6tKplrLpTYK1d1UZBoJph3PSb4lRZA6W76J9kbebRa1v647dUdgZAWwHRf7ZCK6aCm0iTyasM7CaYaNZCkIOYfxhxAlUQtQDzDIQDCZCygZD',
    'Content-Type': 'application/json'
}

# List of recipient phone numbers
phone_numbers = [
    "916382293288",  # +91 63822 93288
    "917871937373",  # +91 78719 37373
    "916381553551",  # +91 63815 53551
    "916379613654"   # +91 63796 13654
]

# Iterate over the phone numbers and send the message
for number in phone_numbers:
    # Define the message payload for each number
    payload = {
        "messaging_product": "whatsapp",
        "to": number,
        "type": "template",
        "template": {
            "name": "hello_world",
            "language": {
                "code": "en_US"
            }
        }
    }
    
    # Send the POST request
    response = requests.post(url, json=payload, headers=headers)
    
    # Check the response status
    if response.status_code == 200:
        print(f"Message successfully sent to {number}")
    else:
        print(f"Failed to send message to {number}: {response.status_code} - {response.text}")
# Out:
# Message successfully sent to 916382293288
# Message successfully sent to 917871937373
# Message successfully sent to 916381553551
# Message successfully sent to 916379613654
