# %%
pip install twilio
# Out:
# Requirement already satisfied: twilio in c:\users\jahag\anaconda3\lib\site-packages (9.2.3)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jahag\anaconda3\lib\site-packages (from twilio) (2.32.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\jahag\anaconda3\lib\site-packages (from twilio) (2.8.0)
# Requirement already satisfied: aiohttp>=3.8.4 in c:\users\jahag\anaconda3\lib\site-packages (from twilio) (3.9.5)
# Requirement already satisfied: aiohttp-retry>=2.8.3 in c:\users\jahag\anaconda3\lib\site-packages (from twilio) (2.8.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jahag\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jahag\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jahag\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jahag\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jahag\anaconda3\lib\site-packages (from aiohttp>=3.8.4->twilio) (1.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jahag\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jahag\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jahag\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jahag\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from twilio.rest import Client

# %%
account_sid = "ACcd0d88307fcfd80e81de7e8885fe2d3f"
auth_token = "fcac17f33fa681e4289c6871c800b005"

client = Client(account_sid, auth_token)

message = client.messages.create(
    body = "This is SOS Alert",
    from_ = "+12562239694",
    to = "+916382293288"
)

print("MESSAGE SENT TO SREE PRIYANTH")
# Out:
# MESSAGE SENT TO SREE PRIYANTH

# %%
account_sid = "ACcd0d88307fcfd80e81de7e8885fe2d3f"
auth_token = "fcac17f33fa681e4289c6871c800b005"

client = Client(account_sid, auth_token)

message = client.messages.create(
    body = "This is SOS Alert",
    from_ = "+12562239694",
    to = "+916379613654"
)

print("MESSAGE SENT TO JAHA")
# Out:
# MESSAGE SENT TO JAHA

# %%
account_sid = "ACcd0d88307fcfd80e81de7e8885fe2d3f"
auth_token = "fcac17f33fa681e4289c6871c800b005"

client = Client(account_sid, auth_token)

message = client.messages.create(
    body = "This is SOS Alert",
    from_ = "+12562239694",
    to = "+917871937373"
)

print("MESSAGE SENT TO MATHAV")
# Out:
# MESSAGE SENT TO MATHAV
